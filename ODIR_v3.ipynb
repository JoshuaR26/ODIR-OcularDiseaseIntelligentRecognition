# %% [markdown]
# # <u> Ocular Cataract Intelligent Recognition (OCIR) </u>
#
# <i>Leveraging the power of Deep Learning, our trained Convolutional Neural Network(CNN) model aims to detect one of the most common ocular conditions- Cataract.</i>
#
# <u><i>Project Team:</i></u>
# 1. Joshua S Raju 22BAI1213
# 2. Md Rameez Haider 22BRS1327
# 3. Shubham Yadav 22BAI1427
#
#
# <b><u>DISCLAIMER:</b></u> <i>While our CNN model aids in cataract detection, it is not a substitute for professional medical advice. Please consult a qualified healthcare provider for a comprehensive eye examination and diagnosis.</i>
#
#
# <b>DATASET:</b>
# https://www.kaggle.com/datasets/andrewmvd/ocular-disease-recognition-odir5k
# https://www.kaggle.com/datasets/jr2ngb/cataractdataset

# %% [markdown]
# ## Importing Dependencies

# %%
import numpy as np
import os

import cv2
import matplotlib.pylab as plt
import imghdr

import tensorflow as tf

# %% [markdown]
# Tensorflow GPU Management

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# ## Cleaning Image Data

# %%
data_dir = 'imgdata_v3'

# %%
img_exts = ['jpeg', 'jpg', 'png']
img_exts
# Out:
# ['jpeg', 'jpg', 'png']

# %%
# from PIL import ImageFile
# ImageFile.LOAD_TRUNCATED_IMAGES = True

for image_class in os.listdir(data_dir):
    for image in os.listdir(os.path.join(data_dir, image_class)):
        img_path = os.path.join(data_dir, image_class,image)
        img = plt.imread(img_path)
        ext = imghdr.what(img_path)
        try:
            if ext not in img_exts:
                os.remove(img_path)
                print('{} successfully removed'.format(img_path))
        except Error as e :
                print('Issue with {}'.format(img_path))

# %% [markdown]
# ## Image Enhancement Functions
#
#  <i>Crop Function</i>

# %%
lower = np.array([0,0,0])
higher = np.array([30,30,30])

def crop(image):
    img_copy = image.copy()
    mask  = cv2.inRange(image, lower, higher)
    inverted_mask = cv2.bitwise_not(mask)

    cont,_ = cv2.findContours(inverted_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    cv2.drawContours(image, cont, -1, 255, 10)

    c = max(cont, key=cv2.contourArea)
    x,y,w,h = cv2.boundingRect(c)
    img_cropped = img_copy[y:y+h, x:x+w]

    print('{} successfully cropped'.format(img_path))
    
    return img_cropped

# %% [markdown]
# <i>Contour Detection Function</i>

# %%
lower = np.array([0,0,0])
higher = np.array([30,30,30])

def contour(image):
    mask  = cv2.inRange(image, lower, higher)
    inverted_mask = cv2.bitwise_not(mask)
    cont,_ = cv2.findContours(inverted_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    
    return len(cont)

# %% [markdown]
# <i> Sharpening Function </i>

# %%
kernel_sharpen = np.array([[-1,-1,-1],
                          [-1,9,-1],
                          [-1,-1,-1]])

def sharpen(image):
    img_sharpen = cv2.filter2D(image, -1, kernel_sharpen)

    return img_sharpen

# %% [markdown]
# <i> Save Function </i>

# %%
def save(path, image):
    plt.imsave(path, image)

# %% [markdown]
# ### PreProcessing Image

# %%
for image_class in os.listdir(data_dir):
    for image in os.listdir(os.path.join(data_dir, image_class)):
        img_path = os.path.join(data_dir, image_class,image)
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        
        if img[0][0][0] == 255:
            os.remove(img_path)
            print('{} White-background image successfully removed'.format(img_path))
        elif img.shape[0] != img.shape[1]:
            img_crop = crop(img)
            img_resize = cv2.resize(img_crop, (512,512))
            img_sharpen = sharpen(img_resize)
            save(img_path, img_sharpen)
        # elif contour(img)>1:
        #     os.remove(img_path)
        #     print('{} Non-transformable image removed'.format(img_path))
        else:
            img_resize = cv2.resize(img, (512,512))
            img_sharpen = sharpen(img_resize)
            save(img_path, img_sharpen)
# Out:
# imgdata_v3\cataract\2174_right.jpg White-background image successfully removed
# imgdata_v3\cataract\2175_left.jpg White-background image successfully removed
# imgdata_v3\cataract\2176_left.jpg White-background image successfully removed
# imgdata_v3\cataract\2177_right.jpg White-background image successfully removed
# imgdata_v3\cataract\2178_right.jpg White-background image successfully removed
# imgdata_v3\cataract\2179_right.jpg White-background image successfully removed
# imgdata_v3\cataract\2180_left.jpg White-background image successfully removed
# imgdata_v3\cataract\2180_right.jpg White-background image successfully removed
# imgdata_v3\cataract\2181_left.jpg White-background image successfully removed
# imgdata_v3\cataract\2181_right.jpg White-background image successfully removed
# imgdata_v3\cataract\2182_left.jpg White-background image successfully removed
# imgdata_v3\cataract\2182_right.jpg White-background image successfully removed
# imgdata_v3\cataract\cataract_001.png successfully cropped
# imgdata_v3\cataract\cataract_002.png successfully cropped
# imgdata_v3\cataract\cataract_003.png successfully cropped
# imgdata_v3\cataract\cataract_004.png successfully cropped
# imgdata_v3\cataract\cataract_005.png successfully cropped
# imgdata_v3\cataract\cataract_006.png successfully cropped
# imgdata_v3\cataract\cataract_007.png successfully cropped
# imgdata_v3\cataract\cataract_008.png successfully cropped
# imgdata_v3\cataract\cataract_009.png successfully cropped
# imgdata_v3\cataract\cataract_010.png successfully cropped
# imgdata_v3\cataract\cataract_011.png successfully cropped
# imgdata_v3\cataract\cataract_012.png successfully cropped
# imgdata_v3\cataract\cataract_013.png successfully cropped
# imgdata_v3\cataract\cataract_014.png successfully cropped
# imgdata_v3\cataract\cataract_015.png successfully cropped
# imgdata_v3\cataract\cataract_016.png successfully cropped
# imgdata_v3\cataract\cataract_017.png successfully cropped
# imgdata_v3\cataract\cataract_018.png successfully cropped
# imgdata_v3\cataract\cataract_019.png successfully cropped
# imgdata_v3\cataract\cataract_020.png successfully cropped
# imgdata_v3\cataract\cataract_021.png successfully cropped
# imgdata_v3\cataract\cataract_022.png successfully cropped
# imgdata_v3\cataract\cataract_023.png successfully cropped
# imgdata_v3\cataract\cataract_024.png successfully cropped
# imgdata_v3\cataract\cataract_025.png successfully cropped
# imgdata_v3\cataract\cataract_026.png successfully cropped
# imgdata_v3\cataract\cataract_027.png successfully cropped
# imgdata_v3\cataract\cataract_028.png successfully cropped
# imgdata_v3\cataract\cataract_029.png successfully cropped
# imgdata_v3\cataract\cataract_030.png successfully cropped
# imgdata_v3\cataract\cataract_031.png successfully cropped
# imgdata_v3\cataract\cataract_032.png successfully cropped
# imgdata_v3\cataract\cataract_033.png successfully cropped
# imgdata_v3\cataract\cataract_034.png successfully cropped
# imgdata_v3\cataract\cataract_035.png successfully cropped
# imgdata_v3\cataract\cataract_036.png successfully cropped
# imgdata_v3\cataract\cataract_037.png successfully cropped
# imgdata_v3\cataract\cataract_038.png successfully cropped
# imgdata_v3\cataract\cataract_039.png successfully cropped
# imgdata_v3\cataract\cataract_040.png successfully cropped
# imgdata_v3\cataract\cataract_041.png successfully cropped
# imgdata_v3\cataract\cataract_042.png successfully cropped
# imgdata_v3\cataract\cataract_043.png successfully cropped
# imgdata_v3\cataract\cataract_044.png successfully cropped
# imgdata_v3\cataract\cataract_045.png successfully cropped
# imgdata_v3\cataract\cataract_046.png successfully cropped
# imgdata_v3\cataract\cataract_047.png successfully cropped
# imgdata_v3\cataract\cataract_048.png successfully cropped
# imgdata_v3\cataract\cataract_049.png successfully cropped
# imgdata_v3\cataract\cataract_050.png successfully cropped
# imgdata_v3\cataract\cataract_051.png successfully cropped
# imgdata_v3\cataract\cataract_052.png successfully cropped
# imgdata_v3\cataract\cataract_053.png successfully cropped
# imgdata_v3\cataract\cataract_054.png successfully cropped
# imgdata_v3\cataract\cataract_055.png successfully cropped
# imgdata_v3\cataract\cataract_056.png successfully cropped
# imgdata_v3\cataract\cataract_057.png successfully cropped
# imgdata_v3\cataract\cataract_058.png successfully cropped
# imgdata_v3\cataract\cataract_059.png successfully cropped
# imgdata_v3\cataract\cataract_060.png successfully cropped
# imgdata_v3\cataract\cataract_061.png successfully cropped
# imgdata_v3\cataract\cataract_062.png successfully cropped
# imgdata_v3\cataract\cataract_063.png successfully cropped
# imgdata_v3\cataract\cataract_064.png successfully cropped
# imgdata_v3\cataract\cataract_065.png successfully cropped
# imgdata_v3\cataract\cataract_066.png successfully cropped
# imgdata_v3\cataract\cataract_067.png successfully cropped
# imgdata_v3\cataract\cataract_068.png successfully cropped
# imgdata_v3\cataract\cataract_069.png successfully cropped
# imgdata_v3\cataract\cataract_070.png successfully cropped
# imgdata_v3\cataract\cataract_071.png successfully cropped
# imgdata_v3\cataract\cataract_072.png successfully cropped
# imgdata_v3\cataract\cataract_073.png successfully cropped
# imgdata_v3\cataract\cataract_074.png successfully cropped
# imgdata_v3\cataract\cataract_075.png successfully cropped
# imgdata_v3\cataract\cataract_076.png successfully cropped
# imgdata_v3\cataract\cataract_077.png successfully cropped
# imgdata_v3\cataract\cataract_078.png successfully cropped
# imgdata_v3\cataract\cataract_079.png successfully cropped
# imgdata_v3\cataract\cataract_080.png successfully cropped
# imgdata_v3\cataract\cataract_081.png successfully cropped
# imgdata_v3\cataract\cataract_082.png successfully cropped
# imgdata_v3\cataract\cataract_083.png successfully cropped
# imgdata_v3\cataract\cataract_084.png successfully cropped
# imgdata_v3\cataract\cataract_085.png successfully cropped
# imgdata_v3\cataract\cataract_086.png successfully cropped
# imgdata_v3\cataract\cataract_087.png successfully cropped
# imgdata_v3\cataract\cataract_088.png successfully cropped
# imgdata_v3\cataract\cataract_089.png successfully cropped
# imgdata_v3\cataract\cataract_090.png successfully cropped
# imgdata_v3\cataract\cataract_091.png successfully cropped
# imgdata_v3\cataract\cataract_092.png successfully cropped
# imgdata_v3\cataract\cataract_093.png successfully cropped
# imgdata_v3\cataract\cataract_094.png successfully cropped
# imgdata_v3\cataract\cataract_095.png successfully cropped
# imgdata_v3\cataract\cataract_096.png successfully cropped
# imgdata_v3\cataract\cataract_097.png successfully cropped
# imgdata_v3\cataract\cataract_098.png successfully cropped
# imgdata_v3\cataract\cataract_099.png successfully cropped
# imgdata_v3\cataract\cataract_100.png successfully cropped
# imgdata_v3\cataract\_130_3561448.jpg White-background image successfully removed
# imgdata_v3\cataract\_130_7837321.jpg White-background image successfully removed
# imgdata_v3\cataract\_131_7587386.jpg White-background image successfully removed
# imgdata_v3\cataract\_131_863673.jpg White-background image successfully removed
# imgdata_v3\cataract\_132_7102134.jpg White-background image successfully removed
# imgdata_v3\cataract\_133_1300923.jpg White-background image successfully removed
# imgdata_v3\cataract\_135_5639464.jpg White-background image successfully removed
# imgdata_v3\cataract\_135_7789155.jpg White-background image successfully removed
# imgdata_v3\cataract\_137_7856304.jpg White-background image successfully removed
# imgdata_v3\cataract\_138_1949117.jpg White-background image successfully removed
# imgdata_v3\cataract\_139_583821.jpg White-background image successfully removed
# imgdata_v3\cataract\_140_1534199.jpg White-background image successfully removed
# imgdata_v3\cataract\_141_3457945.jpg White-background image successfully removed
# imgdata_v3\cataract\_141_9740629.jpg White-background image successfully removed
# imgdata_v3\cataract\_142_7918627.jpg White-background image successfully removed
# imgdata_v3\cataract\_143_1247400.jpg White-background image successfully removed
# imgdata_v3\cataract\_143_9392801.jpg White-background image successfully removed
# imgdata_v3\normal\2957_left.jpg White-background image successfully removed
# imgdata_v3\normal\2957_right.jpg White-background image successfully removed

# %% [markdown]
# ## Data Augmentation

# %%
from keras.preprocessing.image import ImageDataGenerator

# %%
datagen = ImageDataGenerator(brightness_range=(0.1, 1.5),
                            horizontal_flip=True,
                            vertical_flip=True,
                            fill_mode='nearest')

# %%
for image_class in os.listdir(data_dir):
    for image in os.listdir(os.path.join(data_dir, image_class)):
        img_path = os.path.join(data_dir, image_class,image)
        img = cv2.imread(img_path)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        img_reshaped = img.reshape((1,)+img.shape)
        
        i=0
        for batch in datagen.flow(img_reshaped,
                                 batch_size=1,
                                 save_to_dir=os.path.join(data_dir, image_class),
                                 save_prefix='DA',
                                 save_format='jpg'):
            i+=1
            if i>2:
                break

# %% [markdown]
# ## Creating Image Dataset

# %%
dataset = tf.keras.utils.image_dataset_from_directory(data_dir, image_size=(256, 256))
# Out:
# Found 7437 files belonging to 2 classes.

# %%
batch = dataset.as_numpy_iterator().next()
len(batch)
# Out:
# 2

# %%
classes = ['cataract', 'normal']
classes
# Out:
# ['cataract', 'normal']

# %%
fig, axs = plt.subplots(5,5, figsize=(20,20))
for idx, img in enumerate(batch[0][:25]):
    row = idx//5
    col = idx%5

    axs[row, col].imshow(img.astype(int))
    axs[row, col].axis('off')
    axs[row, col].set_title(classes[batch[1][idx]])

# %% [markdown]
# ## Scaling Dataset

# %%
batch[0][0].shape, batch[0][0].max(), batch[0][0].min()
# Out:
# ((256, 256, 3), 255.0, 0.0)

# %%
data = dataset.map(lambda x,y: (x/255, y))

# %%
print(data.as_numpy_iterator().next()[0][0].shape, 
    data.as_numpy_iterator().next()[0][0].max(), 
    data.as_numpy_iterator().next()[0][0].min())
# Out:
# (256, 256, 3) 1.0 0.0

# %% [markdown]
# ## Splitting Dataset

# %%
len(data)
# Out:
# 233

# %%
train_size = int(len(data)*0.7)
val_size = int(len(data)*0.2)+1
test_size = int(len(data)*0.1)

train_size + val_size + test_size
# Out:
# 233

# %%
train_data = data.take(train_size)
val_data = data.skip(train_size).take(val_size)
test_data = data.skip(train_size+val_size).take(test_size)

# %% [markdown]
# ## Training CNN Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()

model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,3)))
model.add(MaxPooling2D())
model.add(Dropout(0.4))

model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Dropout(0.5))

model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Dropout(0.3))

model.add(Flatten())

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics='accuracy')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 16)     0
#  )
#
#  dropout (Dropout)           (None, 127, 127, 16)      0
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 62, 62, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 16)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 30, 30, 16)        0
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 256)               3686656
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 3,696,625
# Trainable params: 3,696,625
# Non-trainable params: 0
# _________________________________________________________________

# %%
logdir = 'LogDir'

try:
    os.mkdir(logdir)
except Exception as e:
    pass    

tfb_callback = tf.keras.callbacks.TensorBoard(logdir)

# %%
model_fit = model.fit(train_data, epochs=30, shuffle=True, validation_data=val_data, callbacks=[tfb_callback])
# Out:
# Epoch 1/30
# 163/163 [==============================] - 26s 52ms/step - loss: 0.8137 - accuracy: 0.6426 - val_loss: 0.5816 - val_accuracy: 0.8125
# Epoch 2/30
# 163/163 [==============================] - 8s 50ms/step - loss: 0.3921 - accuracy: 0.8345 - val_loss: 0.4558 - val_accuracy: 0.8072
# Epoch 3/30
# 163/163 [==============================] - 8s 50ms/step - loss: 0.3174 - accuracy: 0.8710 - val_loss: 0.3965 - val_accuracy: 0.8743
# Epoch 4/30
# 163/163 [==============================] - 8s 51ms/step - loss: 0.2701 - accuracy: 0.8913 - val_loss: 0.3792 - val_accuracy: 0.8690
# Epoch 5/30
# 163/163 [==============================] - 8s 51ms/step - loss: 0.2448 - accuracy: 0.8942 - val_loss: 0.3689 - val_accuracy: 0.8584
# Epoch 6/30
# 163/163 [==============================] - 8s 50ms/step - loss: 0.2317 - accuracy: 0.9001 - val_loss: 0.3576 - val_accuracy: 0.8551
# Epoch 7/30
# 163/163 [==============================] - 8s 51ms/step - loss: 0.2121 - accuracy: 0.9059 - val_loss: 0.3331 - val_accuracy: 0.8703
# Epoch 8/30
# 163/163 [==============================] - 9s 53ms/step - loss: 0.1948 - accuracy: 0.9122 - val_loss: 0.2914 - val_accuracy: 0.8763
# Epoch 9/30
# 163/163 [==============================] - 9s 52ms/step - loss: 0.1853 - accuracy: 0.9141 - val_loss: 0.2383 - val_accuracy: 0.9282
# Epoch 10/30
# 163/163 [==============================] - 9s 58ms/step - loss: 0.1939 - accuracy: 0.9153 - val_loss: 0.2767 - val_accuracy: 0.9096
# Epoch 11/30
# 163/163 [==============================] - 9s 52ms/step - loss: 0.1790 - accuracy: 0.9168 - val_loss: 0.2277 - val_accuracy: 0.8949
# Epoch 12/30
# 163/163 [==============================] - 10s 60ms/step - loss: 0.1639 - accuracy: 0.9262 - val_loss: 0.2442 - val_accuracy: 0.8816
# Epoch 13/30
# 163/163 [==============================] - 10s 59ms/step - loss: 0.1774 - accuracy: 0.9218 - val_loss: 0.2419 - val_accuracy: 0.9242
# Epoch 14/30
# 163/163 [==============================] - 9s 54ms/step - loss: 0.1500 - accuracy: 0.9308 - val_loss: 0.2039 - val_accuracy: 0.9235
# Epoch 15/30
# 163/163 [==============================] - 10s 58ms/step - loss: 0.1502 - accuracy: 0.9363 - val_loss: 0.2004 - val_accuracy: 0.9162
# Epoch 16/30
# 163/163 [==============================] - 9s 53ms/step - loss: 0.1421 - accuracy: 0.9356 - val_loss: 0.1674 - val_accuracy: 0.9415
# Epoch 17/30
# 163/163 [==============================] - 9s 52ms/step - loss: 0.1398 - accuracy: 0.9406 - val_loss: 0.1788 - val_accuracy: 0.9328
# Epoch 18/30
# 163/163 [==============================] - 9s 53ms/step - loss: 0.1375 - accuracy: 0.9365 - val_loss: 0.1674 - val_accuracy: 0.9382
# Epoch 19/30
# 163/163 [==============================] - 9s 53ms/step - loss: 0.1190 - accuracy: 0.9471 - val_loss: 0.1684 - val_accuracy: 0.9235
# Epoch 20/30
# 163/163 [==============================] - 8s 51ms/step - loss: 0.1276 - accuracy: 0.9440 - val_loss: 0.1867 - val_accuracy: 0.9242
# Epoch 21/30
# 163/163 [==============================] - 8s 50ms/step - loss: 0.1205 - accuracy: 0.9467 - val_loss: 0.1420 - val_accuracy: 0.9441
# Epoch 22/30
# 163/163 [==============================] - 8s 50ms/step - loss: 0.1130 - accuracy: 0.9511 - val_loss: 0.1321 - val_accuracy: 0.9488
# Epoch 23/30
# 163/163 [==============================] - 8s 49ms/step - loss: 0.1243 - accuracy: 0.9484 - val_loss: 0.1302 - val_accuracy: 0.9515
# Epoch 24/30
# 163/163 [==============================] - 9s 53ms/step - loss: 0.1191 - accuracy: 0.9532 - val_loss: 0.1372 - val_accuracy: 0.9455
# Epoch 25/30
# 163/163 [==============================] - 8s 48ms/step - loss: 0.1058 - accuracy: 0.9546 - val_loss: 0.1401 - val_accuracy: 0.9368
# Epoch 26/30
# 163/163 [==============================] - 8s 50ms/step - loss: 0.0919 - accuracy: 0.9626 - val_loss: 0.1225 - val_accuracy: 0.9548
# Epoch 27/30
# 163/163 [==============================] - 8s 50ms/step - loss: 0.0987 - accuracy: 0.9611 - val_loss: 0.1107 - val_accuracy: 0.9621
# Epoch 28/30
# 163/163 [==============================] - 9s 52ms/step - loss: 0.0898 - accuracy: 0.9645 - val_loss: 0.1180 - val_accuracy: 0.9515
# Epoch 29/30
# 163/163 [==============================] - 10s 59ms/step - loss: 0.0997 - accuracy: 0.9605 - val_loss: 0.1187 - val_accuracy: 0.9555
# Epoch 30/30
# 163/163 [==============================] - 9s 55ms/step - loss: 0.0848 - accuracy: 0.9647 - val_loss: 0.1187 - val_accuracy: 0.9481

# %% [markdown]
# ## Model Performance

# %%
fig, axs = plt.subplots(2,1, figsize=(8,8))
axs[0].plot(model_fit.history['loss'], color='red', label='Loss')
axs[0].plot(model_fit.history['val_loss'], color='orange', label='Val_Loss')
axs[0].legend(loc='upper right')


axs[1].plot(model_fit.history['accuracy'], color='green', label='Accuracy')
axs[1].plot(model_fit.history['val_accuracy'], color='teal', label='Val_Accuracy')
axs[1].legend(loc='upper left')

# %% [markdown]
# ## Evaluating Model

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
pre = Precision()
rec = Recall()
acc = BinaryAccuracy()

# %%
for batch in test_data.as_numpy_iterator():
    X, y = batch
    y_pred = model.predict(X)
    pre.update_state(y, y_pred)
    rec.update_state(y, y_pred)
    acc.update_state(y, y_pred)
# Out:
# 1/1 [==============================] - 0s 129ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 224ms/step

# %%
print('Accuracy: ', acc.result().numpy())
print('Precision: ', pre.result().numpy())
print('Recall: ', rec.result().numpy())
# Out:
# Accuracy:  0.9456067
# Precision:  0.97720796
# Recall:  0.9171123

# %% [markdown]
# ## Exporting Model

# %%
model.save(os.path.join('models','ODIR_Cataract.h5'))

# %%
from tensorflow.keras.models import load_model

# %%
new_model = load_model(os.path.join('models','ODIR_Cataract.h5'))
new_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 16)     0
#  )
#
#  dropout (Dropout)           (None, 127, 127, 16)      0
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 62, 62, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 16)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 30, 30, 16)        0
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 256)               3686656
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 3,696,625
# Trainable params: 3,696,625
# Non-trainable params: 0
# _________________________________________________________________
