# %% [markdown]
# ## Importing Dependencies

# %%
import os
import numpy as np

import cv2
import matplotlib.pylab as plt

import tensorflow as tf

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# ## Loading Datasets

# %%
train_dir = 'imgdata_v2/split_dataset/train/'
test_dir = 'imgdata_v2/split_dataset/test/'
val_dir = 'imgdata_v2/split_dataset/val/'

# %%
train_dataset = tf.keras.utils.image_dataset_from_directory(train_dir, image_size=(256, 256))
val_dataset = tf.keras.utils.image_dataset_from_directory(val_dir, image_size=(256, 256))
# Out:
# Found 1456 files belonging to 2 classes.
# Found 415 files belonging to 2 classes.

# %% [markdown]
# ## Scaling Dataset

# %%
train_dataset.as_numpy_iterator().next()[0][0].max()
# Out:
# 255.0

# %%
train_data = train_dataset.map(lambda x, y: (x/255, y))

# %%
train_data.as_numpy_iterator().next()[0][0].max()
# Out:
# 1.0

# %%
val_data = val_dataset.map(lambda x, y: (x/255, y))

# %% [markdown]
# ## CNN Model Architecture

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()

model.add(Conv2D(16,(3,3), 3, activation='relu', input_shape=(256, 256, 3)))
model.add(MaxPooling2D())
model.add(Dropout(0.5))

model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Dropout(0.5))

model.add(Conv2D(8, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=tf.optimizers.Adam(), loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])
# model.summary()

# %%
logdir = 'LogDir'

try:
    os.mkdir(logdir)
except Exception as e:
    pass    

tfb_callback = tf.keras.callbacks.TensorBoard(logdir)

# %%
model_fit = model.fit(train_data, 
                      epochs=50, 
                      shuffle=True, 
                      validation_data=val_data, 
                      callbacks=[tfb_callback])
# Out:
# Epoch 1/50
# 46/46 [==============================] - 3s 50ms/step - loss: 0.6978 - accuracy: 0.5288 - val_loss: 0.6884 - val_accuracy: 0.5157
# Epoch 2/50
# 46/46 [==============================] - 2s 45ms/step - loss: 0.6269 - accuracy: 0.6456 - val_loss: 0.6642 - val_accuracy: 0.5373
# Epoch 3/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.5888 - accuracy: 0.7012 - val_loss: 0.6530 - val_accuracy: 0.6530
# Epoch 4/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.5018 - accuracy: 0.7740 - val_loss: 0.6093 - val_accuracy: 0.7157
# Epoch 5/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.4005 - accuracy: 0.8345 - val_loss: 0.5082 - val_accuracy: 0.8096
# Epoch 6/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.4665 - accuracy: 0.7940 - val_loss: 0.5524 - val_accuracy: 0.7807
# Epoch 7/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.3643 - accuracy: 0.8530 - val_loss: 0.5106 - val_accuracy: 0.7855
# Epoch 8/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.3477 - accuracy: 0.8688 - val_loss: 0.4562 - val_accuracy: 0.8506
# Epoch 9/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.3310 - accuracy: 0.8764 - val_loss: 0.4451 - val_accuracy: 0.8337
# Epoch 10/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.3197 - accuracy: 0.8688 - val_loss: 0.4126 - val_accuracy: 0.8482
# Epoch 11/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.3396 - accuracy: 0.8551 - val_loss: 0.4544 - val_accuracy: 0.8458
# Epoch 12/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.3464 - accuracy: 0.8544 - val_loss: 0.4338 - val_accuracy: 0.8578
# Epoch 13/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.3301 - accuracy: 0.8688 - val_loss: 0.4092 - val_accuracy: 0.8602
# Epoch 14/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.2966 - accuracy: 0.8743 - val_loss: 0.4429 - val_accuracy: 0.7904
# Epoch 15/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.2851 - accuracy: 0.8812 - val_loss: 0.3919 - val_accuracy: 0.8241
# Epoch 16/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.2783 - accuracy: 0.8805 - val_loss: 0.3481 - val_accuracy: 0.8795
# Epoch 17/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.2846 - accuracy: 0.8812 - val_loss: 0.3475 - val_accuracy: 0.8819
# Epoch 18/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.2661 - accuracy: 0.8935 - val_loss: 0.3574 - val_accuracy: 0.8578
# Epoch 19/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.2771 - accuracy: 0.8812 - val_loss: 0.3526 - val_accuracy: 0.8627
# Epoch 20/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.2763 - accuracy: 0.8839 - val_loss: 0.3333 - val_accuracy: 0.8795
# Epoch 21/50
# 46/46 [==============================] - 2s 45ms/step - loss: 0.2563 - accuracy: 0.8949 - val_loss: 0.3332 - val_accuracy: 0.8651
# Epoch 22/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.2559 - accuracy: 0.8915 - val_loss: 0.3677 - val_accuracy: 0.8458
# Epoch 23/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.2639 - accuracy: 0.8901 - val_loss: 0.3122 - val_accuracy: 0.9060
# Epoch 24/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.2491 - accuracy: 0.8942 - val_loss: 0.3150 - val_accuracy: 0.8988
# Epoch 25/50
# 46/46 [==============================] - 2s 46ms/step - loss: 0.2416 - accuracy: 0.8874 - val_loss: 0.3476 - val_accuracy: 0.8554
# Epoch 26/50
# 46/46 [==============================] - 2s 45ms/step - loss: 0.2603 - accuracy: 0.8908 - val_loss: 0.3247 - val_accuracy: 0.8627
# Epoch 27/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.2748 - accuracy: 0.8819 - val_loss: 0.3271 - val_accuracy: 0.8675
# Epoch 28/50
# 46/46 [==============================] - 2s 45ms/step - loss: 0.2507 - accuracy: 0.8922 - val_loss: 0.2794 - val_accuracy: 0.8916
# Epoch 29/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.2226 - accuracy: 0.9038 - val_loss: 0.3169 - val_accuracy: 0.8530
# Epoch 30/50
# 46/46 [==============================] - 2s 46ms/step - loss: 0.2513 - accuracy: 0.8929 - val_loss: 0.2788 - val_accuracy: 0.8819
# Epoch 31/50
# 46/46 [==============================] - 2s 45ms/step - loss: 0.2469 - accuracy: 0.8908 - val_loss: 0.2721 - val_accuracy: 0.8940
# Epoch 32/50
# 46/46 [==============================] - 2s 45ms/step - loss: 0.2419 - accuracy: 0.8867 - val_loss: 0.2983 - val_accuracy: 0.8675
# Epoch 33/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.2298 - accuracy: 0.9011 - val_loss: 0.2975 - val_accuracy: 0.8964
# Epoch 34/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.2196 - accuracy: 0.9114 - val_loss: 0.2778 - val_accuracy: 0.8819
# Epoch 35/50
# 46/46 [==============================] - 2s 45ms/step - loss: 0.2171 - accuracy: 0.9032 - val_loss: 0.2513 - val_accuracy: 0.8940
# Epoch 36/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.2267 - accuracy: 0.8997 - val_loss: 0.2575 - val_accuracy: 0.8964
# Epoch 37/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.2216 - accuracy: 0.9121 - val_loss: 0.2483 - val_accuracy: 0.8892
# Epoch 38/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.2126 - accuracy: 0.9073 - val_loss: 0.2608 - val_accuracy: 0.8916
# Epoch 39/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.2107 - accuracy: 0.9038 - val_loss: 0.2705 - val_accuracy: 0.8795
# Epoch 40/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.2541 - accuracy: 0.8819 - val_loss: 0.2616 - val_accuracy: 0.9012
# Epoch 41/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.2198 - accuracy: 0.9004 - val_loss: 0.2402 - val_accuracy: 0.8964
# Epoch 42/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.2289 - accuracy: 0.9004 - val_loss: 0.2362 - val_accuracy: 0.9133
# Epoch 43/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.2065 - accuracy: 0.9045 - val_loss: 0.2704 - val_accuracy: 0.8819
# Epoch 44/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.2009 - accuracy: 0.9169 - val_loss: 0.2450 - val_accuracy: 0.8916
# Epoch 45/50
# 46/46 [==============================] - 2s 44ms/step - loss: 0.2015 - accuracy: 0.9025 - val_loss: 0.2341 - val_accuracy: 0.9108
# Epoch 46/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.2095 - accuracy: 0.9121 - val_loss: 0.2216 - val_accuracy: 0.9108
# Epoch 47/50
# 46/46 [==============================] - 2s 42ms/step - loss: 0.2117 - accuracy: 0.9141 - val_loss: 0.2398 - val_accuracy: 0.9133
# Epoch 48/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.1981 - accuracy: 0.9135 - val_loss: 0.2239 - val_accuracy: 0.9060
# Epoch 49/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.1882 - accuracy: 0.9210 - val_loss: 0.2321 - val_accuracy: 0.8940
# Epoch 50/50
# 46/46 [==============================] - 2s 43ms/step - loss: 0.1943 - accuracy: 0.9183 - val_loss: 0.2169 - val_accuracy: 0.9157

# %% [markdown]
# ## Model Performance

# %%
fig, axs = plt.subplots(1, 2, figsize=(20,5))
axs[0].plot(model_fit.history['loss'], 
            color='red', 
            label='Loss')
axs[0].plot(model_fit.history['val_loss'], 
            color='orange', 
            label='Validation Loss')
axs[0].legend(loc='upper right')
axs[0].set_xlabel('Epochs', fontsize=15)
axs[0].set_ylabel('Loss', fontsize=15)


axs[1].plot(model_fit.history['accuracy'], 
             color='green', 
             label='Accuracy')
axs[1].plot(model_fit.history['val_accuracy'], 
             color='teal', 
             label='Validation Accuracy')
axs[1].legend(loc='upper left')
axs[1].set_xlabel('Epochs', fontsize=15)
axs[1].set_ylabel('Accuracy', fontsize=15)

fig.suptitle('CNN Model Performance Curves', fontsize=20)
# Out:
# Text(0.5, 0.98, 'CNN Model Performance Curves')

# %% [markdown]
# ## Exporting Model

# %%
from keras.models import save_model, load_model

# model.save(os.path.join('models_Reboot/','CNN(NoDataAug)_Re.h5'))

# %%
Model = load_model(os.path.join('models_Reboot/','CNN(NoDataAug)_Re.h5'))

# %%
Model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 85, 85, 16)        448
#
#  max_pooling2d_3 (MaxPooling  (None, 42, 42, 16)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 42, 42, 16)        0
#
#  conv2d_4 (Conv2D)           (None, 40, 40, 16)        2320
#
#  max_pooling2d_4 (MaxPooling  (None, 20, 20, 16)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 20, 20, 16)        0
#
#  conv2d_5 (Conv2D)           (None, 18, 18, 8)         1160
#
#  max_pooling2d_5 (MaxPooling  (None, 9, 9, 8)          0
#  2D)
#
#  dropout_6 (Dropout)         (None, 9, 9, 8)           0
#
#  flatten_1 (Flatten)         (None, 648)               0
#
#  dense_2 (Dense)             (None, 256)               166144
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 170,329
# Trainable params: 170,329
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Evaluating Model

# %%
test_dataset = tf.keras.utils.image_dataset_from_directory(test_dir, image_size=(256, 256))
# Out:
# Found 210 files belonging to 2 classes.

# %%
test_data = test_dataset.map(lambda x, y : (x/255, y))

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

pre = Precision()
acc = BinaryAccuracy()
rec = Recall()

# %%
for batch in test_data.as_numpy_iterator():
    X, y = batch
    y_pred = Model.predict(X)
    
    acc.update_state(y, y_pred)
    pre.update_state(y, y_pred)
    rec.update_state(y, y_pred)
# Out:
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step

# %%
accuracy = acc.result().numpy()
precision = pre.result().numpy()
recall = rec.result().numpy()
f1 = 2 * (precision*recall) / (precision+recall)

print('Accuracy\t:', round(accuracy,5))
print('Precision\t:', round(precision,5))
print('Recall\t\t:', round(recall,5))
print('F1\t\t:', round(f1,5))
# Out:
# Accuracy	: 0.93333
# Precision	: 0.92727
# Recall		: 0.94444
# F1		: 0.93578

# %%
Y=[]
Y_pred=[]
for batch in test_data.as_numpy_iterator():
    X, y = batch
    y_pred = Model.predict(X)
    y_pred = (y_pred > 0.5)
    Y.extend(y)
    Y_pred.extend(y_pred)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y, Y_pred)

plt.figure(figsize=(5, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='copper', cbar=False,
            xticklabels=['Cataract', 'Normal'], yticklabels=['Cataract', 'Normal'])
plt.xlabel('PREDICTED', fontsize=12)
plt.ylabel('TRUE', fontsize=12)
plt.title('CNN Model (Non-Augmented)\nConfusion Matrix', fontsize=15)
plt.show()
# Out:
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
