# %% [markdown]
# ## Importing Dependencies

# %%
import os
import numpy as np

import cv2
import matplotlib.pylab as plt

import tensorflow as tf

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# ## Loading Datasets

# %%
train_dir = 'imgdata_v2/split_dataset/train_aug/'
test_dir = 'imgdata_v2/split_dataset/test/'
val_dir = 'imgdata_v2/split_dataset/val/'

# %%
train_dataset = tf.keras.utils.image_dataset_from_directory(train_dir, image_size=(256, 256))
val_dataset = tf.keras.utils.image_dataset_from_directory(val_dir, image_size=(256, 256))
# Out:
# Found 7051 files belonging to 2 classes.
# Found 415 files belonging to 2 classes.

# %% [markdown]
# ## Scaling Dataset

# %%
train_dataset.as_numpy_iterator().next()[0][0].max()
# Out:
# 255.0

# %%
train_data = train_dataset.map(lambda x, y: (x/255, y))

# %%
train_data.as_numpy_iterator().next()[0][0].max()
# Out:
# 0.8901961

# %%
val_data = val_dataset.map(lambda x, y: (x/255, y))

# %% [markdown]
# ## CNN Model Architecture

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()

model.add(Conv2D(16,(3,3), 3, activation='relu', input_shape=(256, 256, 3)))
model.add(MaxPooling2D())
model.add(Dropout(0.5))

model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Dropout(0.5))

model.add(Conv2D(8, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.1))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=tf.optimizers.Adam(), loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])
# model.summary()

# %%
logdir = 'LogDir'

try:
    os.mkdir(logdir)
except Exception as e:
    pass    

tfb_callback = tf.keras.callbacks.TensorBoard(logdir)

# %%
model_fit = model.fit(train_data, 
                      epochs=30, 
                      shuffle=True, 
                      validation_data=val_data, 
                      callbacks=[tfb_callback])
# Out:
# Epoch 1/30
# 221/221 [==============================] - 5s 19ms/step - loss: 0.6195 - accuracy: 0.6422 - val_loss: 0.5487 - val_accuracy: 0.7783
# Epoch 2/30
# 221/221 [==============================] - 4s 18ms/step - loss: 0.3784 - accuracy: 0.8403 - val_loss: 0.4007 - val_accuracy: 0.8386
# Epoch 3/30
# 221/221 [==============================] - 4s 19ms/step - loss: 0.3229 - accuracy: 0.8657 - val_loss: 0.3548 - val_accuracy: 0.8410
# Epoch 4/30
# 221/221 [==============================] - 4s 18ms/step - loss: 0.3049 - accuracy: 0.8707 - val_loss: 0.3485 - val_accuracy: 0.8289
# Epoch 5/30
# 221/221 [==============================] - 4s 18ms/step - loss: 0.2935 - accuracy: 0.8765 - val_loss: 0.2940 - val_accuracy: 0.8723
# Epoch 6/30
# 221/221 [==============================] - 4s 19ms/step - loss: 0.2584 - accuracy: 0.8915 - val_loss: 0.2638 - val_accuracy: 0.8843
# Epoch 7/30
# 221/221 [==============================] - 4s 19ms/step - loss: 0.2619 - accuracy: 0.8820 - val_loss: 0.2712 - val_accuracy: 0.8675
# Epoch 8/30
# 221/221 [==============================] - 4s 19ms/step - loss: 0.2747 - accuracy: 0.8802 - val_loss: 0.2541 - val_accuracy: 0.8867
# Epoch 9/30
# 221/221 [==============================] - 4s 19ms/step - loss: 0.2453 - accuracy: 0.8953 - val_loss: 0.2302 - val_accuracy: 0.8988
# Epoch 10/30
# 221/221 [==============================] - 4s 18ms/step - loss: 0.2400 - accuracy: 0.8965 - val_loss: 0.2127 - val_accuracy: 0.9036
# Epoch 11/30
# 221/221 [==============================] - 4s 19ms/step - loss: 0.2246 - accuracy: 0.9034 - val_loss: 0.2070 - val_accuracy: 0.9133
# Epoch 12/30
# 221/221 [==============================] - 4s 19ms/step - loss: 0.2138 - accuracy: 0.9077 - val_loss: 0.2160 - val_accuracy: 0.9084
# Epoch 13/30
# 221/221 [==============================] - 4s 19ms/step - loss: 0.2052 - accuracy: 0.9104 - val_loss: 0.1953 - val_accuracy: 0.9157
# Epoch 14/30
# 221/221 [==============================] - 4s 19ms/step - loss: 0.2045 - accuracy: 0.9115 - val_loss: 0.1908 - val_accuracy: 0.9157
# Epoch 15/30
# 221/221 [==============================] - 5s 20ms/step - loss: 0.2043 - accuracy: 0.9114 - val_loss: 0.1890 - val_accuracy: 0.9133
# Epoch 16/30
# 221/221 [==============================] - 5s 20ms/step - loss: 0.1899 - accuracy: 0.9214 - val_loss: 0.1692 - val_accuracy: 0.9181
# Epoch 17/30
# 221/221 [==============================] - 4s 19ms/step - loss: 0.1802 - accuracy: 0.9289 - val_loss: 0.1788 - val_accuracy: 0.9108
# Epoch 18/30
# 221/221 [==============================] - 4s 19ms/step - loss: 0.1724 - accuracy: 0.9285 - val_loss: 0.1562 - val_accuracy: 0.9229
# Epoch 19/30
# 221/221 [==============================] - 4s 19ms/step - loss: 0.1753 - accuracy: 0.9278 - val_loss: 0.1684 - val_accuracy: 0.9349
# Epoch 20/30
# 221/221 [==============================] - 4s 18ms/step - loss: 0.1779 - accuracy: 0.9277 - val_loss: 0.1749 - val_accuracy: 0.9301
# Epoch 21/30
# 221/221 [==============================] - 4s 19ms/step - loss: 0.1686 - accuracy: 0.9319 - val_loss: 0.1558 - val_accuracy: 0.9325
# Epoch 22/30
# 221/221 [==============================] - 4s 19ms/step - loss: 0.1603 - accuracy: 0.9326 - val_loss: 0.1550 - val_accuracy: 0.9277
# Epoch 23/30
# 221/221 [==============================] - 4s 18ms/step - loss: 0.1532 - accuracy: 0.9380 - val_loss: 0.1765 - val_accuracy: 0.9205
# Epoch 24/30
# 221/221 [==============================] - 4s 18ms/step - loss: 0.1550 - accuracy: 0.9383 - val_loss: 0.1537 - val_accuracy: 0.9181
# Epoch 25/30
# 221/221 [==============================] - 4s 18ms/step - loss: 0.1488 - accuracy: 0.9392 - val_loss: 0.1614 - val_accuracy: 0.9301
# Epoch 26/30
# 221/221 [==============================] - 4s 18ms/step - loss: 0.1438 - accuracy: 0.9426 - val_loss: 0.1497 - val_accuracy: 0.9349
# Epoch 27/30
# 221/221 [==============================] - 4s 18ms/step - loss: 0.1458 - accuracy: 0.9406 - val_loss: 0.1508 - val_accuracy: 0.9301
# Epoch 28/30
# 221/221 [==============================] - 4s 19ms/step - loss: 0.1344 - accuracy: 0.9450 - val_loss: 0.1522 - val_accuracy: 0.9229
# Epoch 29/30
# 221/221 [==============================] - 4s 18ms/step - loss: 0.1424 - accuracy: 0.9411 - val_loss: 0.1517 - val_accuracy: 0.9277
# Epoch 30/30
# 221/221 [==============================] - 4s 18ms/step - loss: 0.1301 - accuracy: 0.9467 - val_loss: 0.1586 - val_accuracy: 0.9253

# %% [markdown]
# ## Model Performance

# %%
fig, axs = plt.subplots(1, 2, figsize=(20,5))
axs[0].plot(model_fit.history['loss'], 
            color='red', 
            label='Loss')
axs[0].plot(model_fit.history['val_loss'], 
            color='orange', 
            label='Validation Loss')
axs[0].legend(loc='upper right')
axs[0].set_xlabel('Epochs', fontsize=15)
axs[0].set_ylabel('Loss', fontsize=15)


axs[1].plot(model_fit.history['accuracy'], 
             color='green', 
             label='Accuracy')
axs[1].plot(model_fit.history['val_accuracy'], 
             color='teal', 
             label='Validation Accuracy')
axs[1].legend(loc='upper left')
axs[1].set_xlabel('Epochs', fontsize=15)
axs[1].set_ylabel('Accuracy', fontsize=15)

fig.suptitle('CNN Model Performance Curves', fontsize=20)
# Out:
# Text(0.5, 0.98, 'CNN Model Performance Curves')

# %% [markdown]
# ## Exporting Model

# %%
from keras.models import save_model, load_model

model.save(os.path.join('models_Reboot/','CNN_Re.h5'))

# %%
Model = load_model(os.path.join('models_Reboot/','CNN_Re.h5'))

# %%
Model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_15 (Conv2D)          (None, 85, 85, 16)        448
#
#  max_pooling2d_15 (MaxPoolin  (None, 42, 42, 16)       0
#  g2D)
#
#  dropout_20 (Dropout)        (None, 42, 42, 16)        0
#
#  conv2d_16 (Conv2D)          (None, 40, 40, 16)        2320
#
#  max_pooling2d_16 (MaxPoolin  (None, 20, 20, 16)       0
#  g2D)
#
#  dropout_21 (Dropout)        (None, 20, 20, 16)        0
#
#  conv2d_17 (Conv2D)          (None, 18, 18, 8)         1160
#
#  max_pooling2d_17 (MaxPoolin  (None, 9, 9, 8)          0
#  g2D)
#
#  dropout_22 (Dropout)        (None, 9, 9, 8)           0
#
#  flatten_5 (Flatten)         (None, 648)               0
#
#  dense_10 (Dense)            (None, 256)               166144
#
#  dropout_23 (Dropout)        (None, 256)               0
#
#  dense_11 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 170,329
# Trainable params: 170,329
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Evaluating Model

# %%
test_dataset = tf.keras.utils.image_dataset_from_directory(test_dir, image_size=(256, 256))
# Out:
# Found 210 files belonging to 2 classes.

# %%
test_data = test_dataset.map(lambda x, y : (x/255, y))

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

pre = Precision()
acc = BinaryAccuracy()
rec = Recall()

# %%
for batch in test_data.as_numpy_iterator():
    X, y = batch
    y_pred = Model.predict(X)
    
    acc.update_state(y, y_pred)
    pre.update_state(y, y_pred)
    rec.update_state(y, y_pred)
# Out:
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step

# %%
accuracy = acc.result().numpy()
precision = pre.result().numpy()
recall = rec.result().numpy()
f1 = 2 * (precision*recall) / (precision+recall)

print('Accuracy\t:', round(accuracy,5))
print('Precision\t:', round(precision,5))
print('Recall\t\t:', round(recall,5))
print('F1\t\t:', round(f1,5))
# Out:
# Accuracy	: 0.96667
# Precision	: 0.93913
# Recall		: 1.0
# F1		: 0.96861

# %%
Y=[]
Y_pred=[]
for batch in test_data.as_numpy_iterator():
    X, y = batch
    y_pred = Model.predict(X)
    y_pred = (y_pred > 0.5)
    Y.extend(y)
    Y_pred.extend(y_pred)

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y, Y_pred)

plt.figure(figsize=(5, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='copper', cbar=False,
            xticklabels=['Cataract', 'Normal'], yticklabels=['Cataract', 'Normal'])
plt.xlabel('PREDICTED', fontsize=12)
plt.ylabel('TRUE', fontsize=12)
plt.title('CNN Model Confusion Matrix', fontsize=15)
plt.show()
# Out:
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 31ms/step
