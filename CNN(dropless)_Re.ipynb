# %% [markdown]
# ## Importing Dependencies

# %%
import os
import numpy as np

import cv2
import matplotlib.pylab as plt

import tensorflow as tf

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

# %% [markdown]
# ## Loading Datasets

# %%
train_dir = 'imgdata_v2/split_dataset/train_aug/'
test_dir = 'imgdata_v2/split_dataset/test/'
val_dir = 'imgdata_v2/split_dataset/val/'

# %%
train_dataset = tf.keras.utils.image_dataset_from_directory(train_dir, image_size=(256, 256))
val_dataset = tf.keras.utils.image_dataset_from_directory(val_dir, image_size=(256, 256))
# Out:
# Found 7051 files belonging to 2 classes.
# Found 415 files belonging to 2 classes.

# %% [markdown]
# ## Scaling Dataset

# %%
train_dataset.as_numpy_iterator().next()[0][0].max()
# Out:
# 255.0

# %%
train_data = train_dataset.map(lambda x, y: (x/255, y))

# %%
train_data.as_numpy_iterator().next()[0][0].max()
# Out:
# 1.0

# %%
val_data = val_dataset.map(lambda x, y: (x/255, y))

# %% [markdown]
# ## CNN Model Architecture

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()

model.add(Conv2D(16,(3,3), 3, activation='relu', input_shape=(256, 256, 3)))
model.add(MaxPooling2D())
# model.add(Dropout(0.5))

model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
# model.add(Dropout(0.5))

model.add(Conv2D(8, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
# model.add(Dropout(0.5))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
# model.add(Dropout(0.1))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=tf.optimizers.Adam(), loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])
# model.summary()

# %%
logdir = 'LogDir'

try:
    os.mkdir(logdir)
except Exception as e:
    pass    

tfb_callback = tf.keras.callbacks.TensorBoard(logdir)

# %%
model_fit = model.fit(train_data, 
                      epochs=30, 
                      shuffle=True, 
                      validation_data=val_data, 
                      callbacks=[tfb_callback])
# Out:
# Epoch 1/30
# 221/221 [==============================] - 13s 35ms/step - loss: 0.4151 - accuracy: 0.8033 - val_loss: 0.3760 - val_accuracy: 0.8241
# Epoch 2/30
# 221/221 [==============================] - 8s 33ms/step - loss: 0.2344 - accuracy: 0.8999 - val_loss: 0.2445 - val_accuracy: 0.8916
# Epoch 3/30
# 221/221 [==============================] - 7s 33ms/step - loss: 0.1817 - accuracy: 0.9190 - val_loss: 0.1975 - val_accuracy: 0.9157
# Epoch 4/30
# 221/221 [==============================] - 7s 32ms/step - loss: 0.1728 - accuracy: 0.9260 - val_loss: 0.1912 - val_accuracy: 0.9229
# Epoch 5/30
# 221/221 [==============================] - 7s 32ms/step - loss: 0.1524 - accuracy: 0.9375 - val_loss: 0.1633 - val_accuracy: 0.9253
# Epoch 6/30
# 221/221 [==============================] - 8s 33ms/step - loss: 0.1449 - accuracy: 0.9392 - val_loss: 0.1777 - val_accuracy: 0.9229
# Epoch 7/30
# 221/221 [==============================] - 7s 33ms/step - loss: 0.1201 - accuracy: 0.9506 - val_loss: 0.1946 - val_accuracy: 0.9205
# Epoch 8/30
# 221/221 [==============================] - 8s 34ms/step - loss: 0.1059 - accuracy: 0.9560 - val_loss: 0.1751 - val_accuracy: 0.9157
# Epoch 9/30
# 221/221 [==============================] - 8s 35ms/step - loss: 0.1062 - accuracy: 0.9586 - val_loss: 0.1473 - val_accuracy: 0.9422
# Epoch 10/30
# 221/221 [==============================] - 8s 35ms/step - loss: 0.1014 - accuracy: 0.9607 - val_loss: 0.1337 - val_accuracy: 0.9470
# Epoch 30/30
# 221/221 [==============================] - 8s 36ms/step - loss: 0.0222 - accuracy: 0.9919 - val_loss: 0.2282 - val_accuracy: 0.9470

# %% [markdown]
# ## Model Performance

# %%
fig, axs = plt.subplots(2, 1, figsize=(10,10))
axs[0].plot(model_fit.history['loss'], 
            color='red', 
            label='Loss')
axs[0].plot(model_fit.history['val_loss'], 
            color='orange', 
            label='Validation Loss')
axs[0].legend(loc='upper right')
axs[0].set_xlabel('Epochs', fontsize=15)
axs[0].set_ylabel('Loss', fontsize=15)


axs[1].plot(model_fit.history['accuracy'], 
             color='green', 
             label='Accuracy')
axs[1].plot(model_fit.history['val_accuracy'], 
             color='teal', 
             label='Validation Accuracy')
axs[1].legend(loc='upper left')
axs[1].set_xlabel('Epochs', fontsize=15)
axs[1].set_ylabel('Accuracy', fontsize=15)

fig.suptitle('CNN Model (Without Dropout Layers)\nPerformance Curves', fontsize=20)
# Out:
# Text(0.5, 0.98, 'CNN Model (Without Dropout Layers)\nPerformance Curves')

# %% [markdown]
# ## Exporting Model

# %%
from keras.models import save_model, load_model

model.save(os.path.join('models_Reboot/','CNN(Dropless)_Re.h5'))

# %%
Model = load_model(os.path.join('models_Reboot/','CNN(Dropless)_Re.h5'))

# %%
Model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 85, 85, 16)        448
#
#  max_pooling2d (MaxPooling2D  (None, 42, 42, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 40, 40, 16)        2320
#
#  max_pooling2d_1 (MaxPooling  (None, 20, 20, 16)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 18, 18, 8)         1160
#
#  max_pooling2d_2 (MaxPooling  (None, 9, 9, 8)          0
#  2D)
#
#  flatten (Flatten)           (None, 648)               0
#
#  dense (Dense)               (None, 256)               166144
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 170,329
# Trainable params: 170,329
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Evaluating Model

# %%
test_dataset = tf.keras.utils.image_dataset_from_directory(test_dir, image_size=(256, 256))
# Out:
# Found 210 files belonging to 2 classes.

# %%
test_data = test_dataset.map(lambda x, y : (x/255, y))

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

pre = Precision()
acc = BinaryAccuracy()
rec = Recall()

# %%
for batch in test_data.as_numpy_iterator():
    X, y = batch
    y_pred = Model.predict(X)
    
    acc.update_state(y, y_pred)
    pre.update_state(y, y_pred)
    rec.update_state(y, y_pred)
# Out:
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 102ms/step

# %%
accuracy = acc.result().numpy()
precision = pre.result().numpy()
recall = rec.result().numpy()
f1 = 2 * (precision*recall) / (precision+recall)

print('Accuracy\t:', round(accuracy,5))
print('Precision\t:', round(precision,5))
print('Recall\t\t:', round(recall,5))
print('F1\t\t:', round(f1,5))
# Out:
# Accuracy	: 0.95238
# Precision	: 0.96226
# Recall		: 0.94444
# F1		: 0.95327

# %%
import seaborn as sns

Y=[]
Y_pred=[]
for batch in test_data.as_numpy_iterator():
    X, y = batch
    y_pred = Model.predict(X)
    y_pred = (y_pred > 0.5)
    Y.extend(y)
    Y_pred.extend(y_pred)

from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y, Y_pred)

plt.figure(figsize=(5, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='copper', cbar=False,
            xticklabels=['Cataract', 'Normal'], yticklabels=['Cataract', 'Normal'])
plt.xlabel('PREDICTED', fontsize=12)
plt.ylabel('TRUE', fontsize=12)
plt.title('CNN Model (Without Dropout Layers)\nConfusion Matrix', fontsize=15)
plt.show()
# Out:
# 1/1 [==============================] - 0s 60ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 37ms/step
